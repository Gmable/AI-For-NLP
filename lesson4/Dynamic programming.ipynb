# %% [markdown]
# ## Dynamic programming for Rob Cutting

# %%
original_prices = [1,5,8,9,10,17,17,20,24,30]

# %%
from collections import defaultdict

# %%
price = defaultdict(int)

for i ,p in enumerate(original_prices):
    price[i+1] = p

assert price[1] == 1

# %%
price[132]
# Out:
# 0

# %%
solution = {}
# solution = 
# {
#     4:(2,2)
# }

# %%
def func_1():
    for i in range(n):
        print(n)

# %%
import time

# %%
def func_slow(n):
    start = time.time()
    for i in range(n):
        time.sleep(0.2)
        print('used time:{}'.format(time.time()-start))

# %%
func_slow(5)
# Out:
# used time:0.20046448707580566
# used time:0.40093159675598145
# used time:0.618351936340332
# used time:0.818859338760376
# used time:1.0193097591400146

# %%
def memo(func):
    cache = {}
    @wraps(func)
    def _wrap(n):
        if n in cache: result = cache[n]
        else:
            result = func(n)
            cache[n] = result
        return result
    return

# %%
def r(n):
    max_price, split_point = max(
#         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
        [(price[n],0)] + [(r(i) + r(n-i) , i ) for i  in range (1, n)], key = lambda x: x[0]
#         不能写成[r(n) +r(0)]
    )
    solution[n] = (split_point, n - split_point)
    
    return max_price

# %%
r(4)
# Out:
# 10

# %%
r(123)
#递归，时间复杂度大
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-1f6a7026649f> in <module>()
# ----> 1 r(123)
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in r(n)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# <ipython-input-11-63110b0c646e> in <listcomp>(.0)
#       2     return max(
#       3 #         [p[n], r(1)+r(n-1), r(2) + r(n-2),]
# ----> 4         [price[n]] + [r(i) + r(n-i) for i in range (1, n)]
#       5 #         不能写成[r(n) +r(0)]
#       6     )
#
# KeyboardInterrupt:

# %%
def not_cut(split):
    return split == 0

# %%
def parse_solution(target_length, revenue_solution):
    left, right = revenue_solution[target_length]
    if not_cut(left): return [right]
    return parse_solution(left, revenue_solution) + parse_solution(right, revenue_solution)

# %%
@lru_cache(maxsize=2**10)
def edit_distance(string1,string2):
    
    if len(string1) == 0: return len(string2)
    if len(string2) == 0: return len(string1)   
    
    tail_s1=string1[-1]
    tail_s2=string2[-1]
    
    candidates = [
        
    ]
    
    return min(
        [
            (edit_distance(string1[:-1],string2)+1,'DEL ()'.format(tail_s1)),
            (edit_distance(string1,string2[:-1])+1,'ADD ()'.format(tail_s2)),
            
        ]
        
        if tail_s1 == tail_s2:
            both_forward =(edit_distance(string1[:-1], string2[:-1]) + 0, '')
        
        edit_distance(string1[:-1], string2[:-1]) + (0 if tail_s1 == tail_s2 else 2),
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-a90b97833dfb> in <module>()
# ----> 1 @lru_cache(maxsize=2**10)
#       2 def edit_distance(string1,string2):
#       3
#       4     if len(string1) == 0: return len(string2)
#       5     if len(string2) == 0: return len(string1)
#
# NameError: name 'lru_cache' is not defined

# %%
edit_distance('beijing','biejing')
# Out:
# 2

# %%
edit_distance('我今天确实不太想吃饭','我今天确实不太像吃饭')
# Out:
# 2
